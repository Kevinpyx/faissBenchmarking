# %% [markdown]
# This document will compare the performance of a GPU and CPU for the same algorithm at 10M, 25M, and 50M.
# We will have 5 sets of plots (15 plots) in total in this document. Every set contains a plot for time per query, a plot for memory, and a plot for recall. The first three plots will compare the performance of GPU and CPU for the same algorithm at different data sizes (10M, 25M, 50M, hence three sets). The last two plots will compare the performance of the same algorithm with different data sizes (one for CPU, one for GPU, hence two sets). A hierarchical structure of the plots is shown below.
#
# - **GPU vs CPU**: We'll compare the difference in performance of the same algorithm run on GPU and CPU (two bars per algorithm, one for gpu, one for cpu).
#     - Three plots for 10M data points
#         - One plot for SPQ
#         - One plot for memory
#         - One plot for recall
#     - Three plots for 25M data points
#         - One plot for SPQ
#         - One plot for memory
#         - One plot for recall
#     - Three plots for 50M data points
#         - One plot for SPQ
#         - One plot for memory
#         - One plot for recall
# - **10M & 25M & 50M**: We'll compare the performance of the same algorithm run with different data sizes (three bars per algorithm for different sizes).
#     - Three plots for CPU
#         - One plot for SPQ
#         - One plot for memory
#         - One plot for recall
#     - Three plots for GPU
#         - One plot for SPQ
#         - One plot for memory
#         - One plot for recall

# %%
# import packages
import dataI_O as io
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# - **GPU vs CPU**: We'll compare the performance difference of the same algorithm run on the GPU and CPU (two bars per algorithm).
#     - Three plot for 10M data points
#         - One plot for SPQ
#         - One plot for memory
#         - One plot for recall
#     - Three plot for 25M data points
#         - One plot for SPQ
#         - One plot for memory
#         - One plot for recall
#     - Three plot for 50M data points
#         - One plot for SPQ
#         - One plot for memory
#         - One plot for recall
# - **10M & 25M & 50M**: We'll compare the performance of the same algorithm run with different data sizes (three bars per algorithm for different sizes).
#     - Three plot for CPU
#         - One plot for SPQ
#         - One plot for memory
#         - One plot for recall
#     - Three plot for GPU
#         - One plot for SPQ
#         - One plot for memory
#         - One plot for recall

# %%
# Data preparation
# FlatL2_CPU_10M
FlatL2_CPU_10M = '/home/ypx/faissTesting/benchmark/results/FlatL2_10M_96_10k_100.h5'
FlatL2_CPU_10M = io.load_results(FlatL2_CPU_10M)
avg_FlatL2_CPU_10M = np.mean(FlatL2_CPU_10M, axis=0)

SPQ_FlatL2_CPU_10M = avg_FlatL2_CPU_10M[0,0,3]*1000
memory_FlatL2_CPU_10M = avg_FlatL2_CPU_10M[0,0,4]
recall_FlatL2_CPU_10M = avg_FlatL2_CPU_10M[0,0,5]

# FlatL2_GPU_10M
FlatL2_GPU_10M = '/home/ypx/faissTesting/benchmark/results/FlatL2_10M_96_10k_100_GPU.h5'
FlatL2_GPU_10M = io.load_results(FlatL2_GPU_10M)
avg_FlatL2_GPU_10M = np.mean(FlatL2_GPU_10M, axis=0)

SPQ_FlatL2_GPU_10M = avg_FlatL2_GPU_10M[0,0,3]*1000
memory_FlatL2_GPU_10M = avg_FlatL2_GPU_10M[0,0,4]
recall_FlatL2_GPU_10M = avg_FlatL2_GPU_10M[0,0,5]

# FlatL2_CPU_25M
FlatL2_CPU_25M = '/home/ypx/faissTesting/benchmark/results/FlatL2_25M_96_10k_100.h5'
FlatL2_CPU_25M = io.load_results(FlatL2_CPU_25M)
avg_FlatL2_CPU_25M = np.mean(FlatL2_CPU_25M, axis=0)

SPQ_FlatL2_CPU_25M = avg_FlatL2_CPU_25M[0,0,3]*1000
memory_FlatL2_CPU_25M = avg_FlatL2_CPU_25M[0,0,4]
recall_FlatL2_CPU_25M = avg_FlatL2_CPU_25M[0,0,5]

# FlatL2_GPU_25M
FlatL2_GPU_25M = '/home/ypx/faissTesting/benchmark/results/FlatL2_25M_96_10k_100_GPU.h5'
FlatL2_GPU_25M = io.load_results(FlatL2_GPU_25M)
avg_FlatL2_GPU_25M = np.mean(FlatL2_GPU_25M, axis=0)

SPQ_FlatL2_GPU_25M = avg_FlatL2_GPU_25M[0,0,3]*1000
memory_FlatL2_GPU_25M = avg_FlatL2_GPU_25M[0,0,4]
recall_FlatL2_GPU_25M = avg_FlatL2_GPU_25M[0,0,5]

# FlatL2_CPU_50M
FlatL2_CPU_50M = '/home/ypx/faissTesting/benchmark/results/FlatL2_50M_96_10k_100.h5'
FlatL2_CPU_50M = io.load_results(FlatL2_CPU_50M)
avg_FlatL2_CPU_50M = np.mean(FlatL2_CPU_50M, axis=0)

SPQ_FlatL2_CPU_50M = avg_FlatL2_CPU_50M[0,0,3]*1000
memory_FlatL2_CPU_50M = avg_FlatL2_CPU_50M[0,0,4]
recall_FlatL2_CPU_50M = avg_FlatL2_CPU_50M[0,0,5]

# FlatL2_GPU_50M
FlatL2_GPU_50M = '/home/ypx/faissTesting/benchmark/results/FlatL2_50M_96_10k_100_GPU.h5'
FlatL2_GPU_50M = io.load_results(FlatL2_GPU_50M)
avg_FlatL2_GPU_50M = np.mean(FlatL2_GPU_50M, axis=0)

SPQ_FlatL2_GPU_50M = avg_FlatL2_GPU_50M[0,0,3]*1000
memory_FlatL2_GPU_50M = avg_FlatL2_GPU_50M[0,0,4]
recall_FlatL2_GPU_50M = avg_FlatL2_GPU_50M[0,0,5]

# LSH_CPU_10M
LSH_CPU_10M = '/home/ypx/faissTesting/benchmark/results/LSH_10M_96_10k_100.h5'
LSH_CPU_10M = io.load_results(LSH_CPU_10M)
avg_LSH_CPU_10M = np.mean(LSH_CPU_10M, axis=0)

SPQ_LSH_CPU_10M = avg_LSH_CPU_10M[0,:,3]*1000
memory_LSH_CPU_10M = avg_LSH_CPU_10M[0,:,4]
recall_LSH_CPU_10M = avg_LSH_CPU_10M[0,:,5]

# LSH_GPU_10M
LSH_GPU_10M = '/home/ypx/faissTesting/benchmark/results/LSH_10M_96_10k_100_GPU.h5'
LSH_GPU_10M = io.load_results(LSH_GPU_10M)
avg_LSH_GPU_10M = np.mean(LSH_GPU_10M, axis=0)

SPQ_LSH_GPU_10M = avg_LSH_GPU_10M[0,:,3]*1000
memory_LSH_GPU_10M = avg_LSH_GPU_10M[0,:,4]
recall_LSH_GPU_10M = avg_LSH_GPU_10M[0,:,5]

# LSH_CPU_25M
LSH_CPU_25M = '/home/ypx/faissTesting/benchmark/results/LSH_25M_96_10k_100.h5'
LSH_CPU_25M = io.load_results(LSH_CPU_25M)
avg_LSH_CPU_25M = np.mean(LSH_CPU_25M, axis=0)

SPQ_LSH_CPU_25M = avg_LSH_CPU_25M[0,:,3]*1000
memory_LSH_CPU_25M = avg_LSH_CPU_25M[0,:,4]
recall_LSH_CPU_25M = avg_LSH_CPU_25M[0,:,5]

# LSH_GPU_25M
LSH_GPU_25M = '/home/ypx/faissTesting/benchmark/results/LSH_25M_96_10k_100_GPU.h5'
LSH_GPU_25M = io.load_results(LSH_GPU_25M)
avg_LSH_GPU_25M = np.mean(LSH_GPU_25M, axis=0)

SPQ_LSH_GPU_25M = avg_LSH_GPU_25M[0,:,3]*1000
memory_LSH_GPU_25M = avg_LSH_GPU_25M[0,:,4]
recall_LSH_GPU_25M = avg_LSH_GPU_25M[0,:,5]

# LSH_CPU_50M
LSH_CPU_50M = '/home/ypx/faissTesting/benchmark/results/LSH_50M_96_10k_100.h5'
LSH_CPU_50M = io.load_results(LSH_CPU_50M)
avg_LSH_CPU_50M = np.mean(LSH_CPU_50M, axis=0)

SPQ_LSH_CPU_50M = avg_LSH_CPU_50M[0,:,3]*1000
memory_LSH_CPU_50M = avg_LSH_CPU_50M[0,:,4]
recall_LSH_CPU_50M = avg_LSH_CPU_50M[0,:,5]

# LSH_GPU_50M
LSH_GPU_50M = '/home/ypx/faissTesting/benchmark/results/LSH_50M_96_10k_100_GPU.h5'
LSH_GPU_50M = io.load_results(LSH_GPU_50M)
avg_LSH_GPU_50M = np.mean(LSH_GPU_50M, axis=0)

SPQ_LSH_GPU_50M = avg_LSH_GPU_50M[0,:,3]*1000
memory_LSH_GPU_50M = avg_LSH_GPU_50M[0,:,4]
recall_LSH_GPU_50M = avg_LSH_GPU_50M[0,:,5]

# PQ_CPU_10M
PQ_CPU_10M = '/home/ypx/faissTesting/benchmark/results/PQ_10M_96_10k_100.h5'
PQ_CPU_10M = io.load_results(PQ_CPU_10M)
avg_PQ_CPU_10M = np.mean(PQ_CPU_10M, axis=0)

SPQ_PQ_CPU_10M = avg_PQ_CPU_10M[:,:,3]*1000
memory_PQ_CPU_10M = avg_PQ_CPU_10M[:,:,4]
recall_PQ_CPU_10M = avg_PQ_CPU_10M[:,:,5]

# PQ_GPU_10M
PQ_GPU_10M = '/home/ypx/faissTesting/benchmark/results/PQ_10M_96_10k_100_GPU.h5'
PQ_GPU_10M = io.load_results(PQ_GPU_10M)
avg_PQ_GPU_10M = np.mean(PQ_GPU_10M, axis=0)

SPQ_PQ_GPU_10M = avg_PQ_GPU_10M[:,:,3]*1000
memory_PQ_GPU_10M = avg_PQ_GPU_10M[:,:,4]
recall_PQ_GPU_10M = avg_PQ_GPU_10M[:,:,5]

# PQ_CPU_25M
PQ_CPU_25M = '/home/ypx/faissTesting/benchmark/results/PQ_25M_96_10k_100.h5'
PQ_CPU_25M = io.load_results(PQ_CPU_25M)
avg_PQ_CPU_25M = np.mean(PQ_CPU_25M, axis=0)

SPQ_PQ_CPU_25M = avg_PQ_CPU_25M[:,:,3]*1000
memory_PQ_CPU_25M = avg_PQ_CPU_25M[:,:,4]
recall_PQ_CPU_25M = avg_PQ_CPU_25M[:,:,5]

# PQ_GPU_25M
PQ_GPU_25M = '/home/ypx/faissTesting/benchmark/results/PQ_25M_96_10k_100_GPU.h5'
PQ_GPU_25M = io.load_results(PQ_GPU_25M)
avg_PQ_GPU_25M = np.mean(PQ_GPU_25M, axis=0)

SPQ_PQ_GPU_25M = avg_PQ_GPU_25M[:,:,3]*1000
memory_PQ_GPU_25M = avg_PQ_GPU_25M[:,:,4]
recall_PQ_GPU_25M = avg_PQ_GPU_25M[:,:,5]

# PQ_CPU_50M
PQ_CPU_50M = '/home/ypx/faissTesting/benchmark/results/PQ_50M_96_10k_100.h5'
PQ_CPU_50M = io.load_results(PQ_CPU_50M)
avg_PQ_CPU_50M = np.mean(PQ_CPU_50M, axis=0)

SPQ_PQ_CPU_50M = avg_PQ_CPU_50M[:,:,3]*1000
memory_PQ_CPU_50M = avg_PQ_CPU_50M[:,:,4]
recall_PQ_CPU_50M = avg_PQ_CPU_50M[:,:,5]

# PQ_GPU_50M
PQ_GPU_50M = '/home/ypx/faissTesting/benchmark/results/PQ_50M_96_10k_100_GPU.h5'
PQ_GPU_50M = io.load_results(PQ_GPU_50M)
avg_PQ_GPU_50M = np.mean(PQ_GPU_50M, axis=0)

SPQ_PQ_GPU_50M = avg_PQ_GPU_50M[:,:,3]*1000
memory_PQ_GPU_50M = avg_PQ_GPU_50M[:,:,4]
recall_PQ_GPU_50M = avg_PQ_GPU_50M[:,:,5]

# HNSW_CPU_10M
HNSW_CPU_10M = '/home/ypx/faissTesting/benchmark/results/HNSWFlat_10M_96_10k_100.h5'
HNSW_CPU_10M = io.load_results(HNSW_CPU_10M)
avg_HNSW_CPU_10M = np.mean(HNSW_CPU_10M, axis=0)

SPQ_HNSW_CPU_10M = avg_HNSW_CPU_10M[0,:,3]*1000
memory_HNSW_CPU_10M = avg_HNSW_CPU_10M[0,:,4]
recall_HNSW_CPU_10M = avg_HNSW_CPU_10M[0,:,5]

# HNSW_GPU_10M
HNSW_GPU_10M = '/home/ypx/faissTesting/benchmark/results/HNSWFlat_10M_96_10k_100_GPU.h5'
HNSW_GPU_10M = io.load_results(HNSW_GPU_10M)
avg_HNSW_GPU_10M = np.mean(HNSW_GPU_10M, axis=0)

SPQ_HNSW_GPU_10M = avg_HNSW_GPU_10M[0,:,3]*1000
memory_HNSW_GPU_10M = avg_HNSW_GPU_10M[0,:,4]
recall_HNSW_GPU_10M = avg_HNSW_GPU_10M[0,:,5]

# HNSW_CPU_25M
HNSW_CPU_25M = '/home/ypx/faissTesting/benchmark/results/HNSWFlat_25M_96_10k_100.h5'
HNSW_CPU_25M = io.load_results(HNSW_CPU_25M)
avg_HNSW_CPU_25M = np.mean(HNSW_CPU_25M, axis=0)

SPQ_HNSW_CPU_25M = avg_HNSW_CPU_25M[0,:,3]*1000
memory_HNSW_CPU_25M = avg_HNSW_CPU_25M[0,:,4]
recall_HNSW_CPU_25M = avg_HNSW_CPU_25M[0,:,5]

# HNSW_GPU_25M
HNSW_GPU_25M = '/home/ypx/faissTesting/benchmark/results/HNSWFlat_25M_96_10k_100_GPU.h5'
HNSW_GPU_25M = io.load_results(HNSW_GPU_25M)
avg_HNSW_GPU_25M = np.mean(HNSW_GPU_25M, axis=0)

SPQ_HNSW_GPU_25M = avg_HNSW_GPU_25M[0,:,3]*1000
memory_HNSW_GPU_25M = avg_HNSW_GPU_25M[0,:,4]
recall_HNSW_GPU_25M = avg_HNSW_GPU_25M[0,:,5]

# HNSW_CPU_50M
HNSW_CPU_50M = '/home/ypx/faissTesting/benchmark/results/HNSWFlat_50M_96_10k_100.h5'
HNSW_CPU_50M = io.load_results(HNSW_CPU_50M)
avg_HNSW_CPU_50M = np.mean(HNSW_CPU_50M, axis=0)

SPQ_HNSW_CPU_50M = avg_HNSW_CPU_50M[0,:,3]*1000
memory_HNSW_CPU_50M = avg_HNSW_CPU_50M[0,:,4]
recall_HNSW_CPU_50M = avg_HNSW_CPU_50M[0,:,5]

# HNSW_GPU_50M
HNSW_GPU_50M = '/home/ypx/faissTesting/benchmark/results/HNSWFlat_50M_96_10k_100_GPU.h5'
HNSW_GPU_50M = io.load_results(HNSW_GPU_50M)
avg_HNSW_GPU_50M = np.mean(HNSW_GPU_50M, axis=0)

SPQ_HNSW_GPU_50M = avg_HNSW_GPU_50M[0,:,3]*1000
memory_HNSW_GPU_50M = avg_HNSW_GPU_50M[0,:,4]
recall_HNSW_GPU_50M = avg_HNSW_GPU_50M[0,:,5]


# parameter categories
# LSH
cat_LSH_nbits_10M = [2, 6, 8, 16, 24, 32, 64, 128, 256, 512, 768, 1024]
cat_LSH_nbits_25M = [2, 6, 8, 16, 24, 32, 64, 128, 256]
cat_LSH_nbits_50M = [2, 6, 8, 16, 24, 32, 64, 128]

# PQ
cat_PQ_m_10M = [1, 3, 8, 16, 32, 48]
cat_PQ_nbits_10M = [6, 8, 10]
cat_PQ_m_25M = [8, 32]
cat_PQ_nbits_25M = [8, 10]
cat_PQ_m_50M = [8, 32]
cat_PQ_nbits_50M = [8, 10]

# HNSW
cat_HNSW_M_10M = [16, 32, 64, 96]
cat_HNSW_M_25M = [4, 8]
cat_HNSW_M_50M = [4]

# %% [markdown]
# With the data prepared, let's now plot the results.

# %%
# GPU vs CPU (10M): 
# FlatL2_chosen:
SPQ_FlatL2_CPU_10M_chosen = SPQ_FlatL2_CPU_10M
recall_FlatL2_CPU_10M_chosen = recall_FlatL2_CPU_10M
memory_FlatL2_CPU_10M_chosen = memory_FlatL2_CPU_10M

SPQ_FlatL2_GPU_10M_chosen = SPQ_FlatL2_GPU_10M
recall_FlatL2_GPU_10M_chosen = recall_FlatL2_GPU_10M
memory_FlatL2_GPU_10M_chosen = memory_FlatL2_GPU_10M
categories_FlatL2_chosen = ["Exact search\n(baseline)"]

# LSH_chosen:
idx_LSH_10M_nbits = slice(5, 8)
SPQ_LSH_CPU_10M_chosen = SPQ_LSH_CPU_10M[idx_LSH_10M_nbits]
recall_LSH_CPU_10M_chosen = recall_LSH_CPU_10M[idx_LSH_10M_nbits]
memory_LSH_CPU_10M_chosen = memory_LSH_CPU_10M[idx_LSH_10M_nbits]

SPQ_LSH_GPU_10M_chosen = SPQ_LSH_GPU_10M[idx_LSH_10M_nbits]
recall_LSH_GPU_10M_chosen = recall_LSH_GPU_10M[idx_LSH_10M_nbits]
memory_LSH_GPU_10M_chosen = memory_LSH_GPU_10M[idx_LSH_10M_nbits]
categories_LSH_10M_chosen = ["LSH\nnbits=32", "LSH\nnbits=64", "LSH\nnbits=128"]

# PQ_chosen:
# (m, nbits) = (8, 8), (32, 8), (8, 10) (32, 10) (index: 8, 10, 14, 16) chosen after flattened
# print(SPQ_PQ.shape)
idx_PQ_CPU_10M_chosen = [8, 10, 14, 16]
SPQ_PQ_CPU_10M_flat = SPQ_PQ_CPU_10M.flatten()
recall_PQ_CPU_10M_flat = recall_PQ_CPU_10M.flatten()
memory_PQ_CPU_10M_flat = memory_PQ_CPU_10M.flatten()
SPQ_PQ_CPU_10M_chosen = SPQ_PQ_CPU_10M_flat[idx_PQ_CPU_10M_chosen]
recall_PQ_CPU_10M_chosen = recall_PQ_CPU_10M_flat[idx_PQ_CPU_10M_chosen]
memory_PQ_CPU_10M_chosen = memory_PQ_CPU_10M_flat[idx_PQ_CPU_10M_chosen]
categories_PQ_10M_chosen = ["PQ\nm=8\nnbits=8", "PQ\nm=32\nnbits=8", "PQ\nm=8\nnbits=10", "PQ\nm=32\nnbits=10"]

idx_PQ_GPU_10M_chosen = slice(0,4) # to account for the fact that we only tested 4 configurations of PQ at 10M on GPU
SPQ_PQ_GPU_10M_flat = SPQ_PQ_GPU_10M.flatten()
recall_PQ_GPU_10M_flat = recall_PQ_GPU_10M.flatten()
memory_PQ_GPU_10M_flat = memory_PQ_GPU_10M.flatten()
SPQ_PQ_GPU_10M_chosen = SPQ_PQ_GPU_10M_flat[idx_PQ_GPU_10M_chosen]
recall_PQ_GPU_10M_chosen = recall_PQ_GPU_10M_flat[idx_PQ_GPU_10M_chosen]
memory_PQ_GPU_10M_chosen = memory_PQ_GPU_10M_flat[idx_PQ_GPU_10M_chosen]

# HNSW_chosen:
idx_HNSW_10M_chosen = slice(1,4)
SPQ_HNSW_CPU_10M_chosen = SPQ_HNSW_CPU_10M[idx_HNSW_10M_chosen]
recall_HNSW_CPU_10M_chosen = recall_HNSW_CPU_10M[idx_HNSW_10M_chosen]
memory_HNSW_CPU_10M_chosen = memory_HNSW_CPU_10M[idx_HNSW_10M_chosen]

SPQ_HNSW_GPU_10M_chosen = SPQ_HNSW_GPU_10M[idx_HNSW_10M_chosen]
recall_HNSW_GPU_10M_chosen = recall_HNSW_GPU_10M[idx_HNSW_10M_chosen]
memory_HNSW_GPU_10M_chosen = memory_HNSW_GPU_10M[idx_HNSW_10M_chosen]
categories_HNSW_10M_chosen = ["HNSW\nM=32", "HNSW\nM=64", "HNSW\nM=96"]

# Plot
# Next we create 3 plots: 1) SPQ 2) memory, 3) recall
# For every plot, we plot the results for the methods with chosen parameters on both CPU and GPU (the bar for CPU and GPU are next to each other)
# FlatL2 should be on the left most of every plot as it is the baseline
# The order of the methods on the plot is: FlatL2, LSH, PQ, HNSW
figsize = (15, 5)
categories = categories_FlatL2_chosen + categories_LSH_10M_chosen + categories_PQ_10M_chosen + categories_HNSW_10M_chosen

# SPQ
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True, figsize=figsize)
SPQ_CPU = np.concatenate((SPQ_FlatL2_CPU_10M_chosen.reshape(-1), SPQ_LSH_CPU_10M_chosen, SPQ_PQ_CPU_10M_chosen, SPQ_HNSW_CPU_10M_chosen))
SPQ_GPU = np.concatenate((SPQ_FlatL2_GPU_10M_chosen.reshape(-1), SPQ_LSH_GPU_10M_chosen, SPQ_PQ_GPU_10M_chosen, SPQ_HNSW_GPU_10M_chosen))
ax1.bar(np.arange(len(categories)), SPQ_CPU, width=0.4, label='CPU')
ax1.bar(np.arange(len(categories))+0.4, SPQ_GPU, width=0.4, label='GPU')
#ax1.set_ylabel('Time per query (ms)')
ax1.set_ylim(0.15, 4)
ax1.set_title('Time per query for different methods on 10M dataset')
ax1.legend(loc='best')
ax2.bar(np.arange(len(categories)), SPQ_CPU, width=0.4, label='CPU')
ax2.bar(np.arange(len(categories))+0.4, SPQ_GPU, width=0.4, label='GPU')
ax2.set_ylim(0.003, 0.15)
ax3.bar(np.arange(len(categories)), SPQ_CPU, width=0.4, label='CPU')
ax3.bar(np.arange(len(categories))+0.4, SPQ_GPU, width=0.4, label='GPU')
ax3.set_ylim(0, 0.003)
plt.ylabel('Time per query (ms)')
plt.xlabel('Index')
plt.xticks(np.arange(len(categories))+0.2, categories, rotation=45)
# plt.savefig('/home/ypx/faissTesting/benchmark/charts/SPQ_10M_CPUvsGPU.png')
plt.show()

# Memory
plt.figure(figsize=figsize)
memory_CPU = np.concatenate((memory_FlatL2_CPU_10M_chosen.reshape(-1), memory_LSH_CPU_10M_chosen, memory_PQ_CPU_10M_chosen, memory_HNSW_CPU_10M_chosen))
memory_GPU = np.concatenate((memory_FlatL2_GPU_10M_chosen.reshape(-1), memory_LSH_GPU_10M_chosen, memory_PQ_GPU_10M_chosen, memory_HNSW_GPU_10M_chosen))
plt.bar(np.arange(len(categories)), memory_CPU, width=0.4, label='CPU')
plt.bar(np.arange(len(categories))+0.4, memory_GPU, width=0.4, label='GPU')
plt.ylabel('Memory (MB)')
plt.xlabel('Index')
plt.xticks(np.arange(len(categories))+0.2, categories, rotation=45)
plt.title('Memory usage for different methods on 10M dataset')
plt.legend(loc='best')
# plt.savefig('/home/ypx/faissTesting/benchmark/charts/memory_10M_CPUvsGPU.png')
plt.show()

# Recall
plt.figure(figsize=figsize)
recall_CPU = np.concatenate((recall_FlatL2_CPU_10M_chosen.reshape(-1), recall_LSH_CPU_10M_chosen, recall_PQ_CPU_10M_chosen, recall_HNSW_CPU_10M_chosen))
recall_GPU = np.concatenate((recall_FlatL2_GPU_10M_chosen.reshape(-1), recall_LSH_GPU_10M_chosen, recall_PQ_GPU_10M_chosen, recall_HNSW_GPU_10M_chosen))
plt.bar(np.arange(len(categories)), recall_CPU, width=0.4, label='CPU')
plt.bar(np.arange(len(categories))+0.4, recall_GPU, width=0.4, label='GPU')
plt.ylabel('Recall')
plt.xlabel('Index')
plt.xticks(np.arange(len(categories))+0.2, categories, rotation=45)
plt.title('Recall for different methods on 10M dataset')
plt.legend(loc='best')
# plt.savefig('/home/ypx/faissTesting/benchmark/charts/recall_10M_CPUvsGPU.png')
plt.show()

# %%
# GPU vs CPU (25M): 
# FlatL2_chosen:
SPQ_FlatL2_CPU_25M_chosen = SPQ_FlatL2_CPU_25M
recall_FlatL2_CPU_25M_chosen = recall_FlatL2_CPU_25M
memory_FlatL2_CPU_25M_chosen = memory_FlatL2_CPU_25M

SPQ_FlatL2_GPU_25M_chosen = SPQ_FlatL2_GPU_25M
recall_FlatL2_GPU_25M_chosen = recall_FlatL2_GPU_25M
memory_FlatL2_GPU_25M_chosen = memory_FlatL2_GPU_25M
categories_FlatL2_chosen = ["Exact search\n(baseline)"]

# LSH_chosen:
idx_LSH_25M_nbits = slice(5, 8)
SPQ_LSH_CPU_25M_chosen = SPQ_LSH_CPU_25M[idx_LSH_25M_nbits]
recall_LSH_CPU_25M_chosen = recall_LSH_CPU_25M[idx_LSH_25M_nbits]
memory_LSH_CPU_25M_chosen = memory_LSH_CPU_25M[idx_LSH_25M_nbits]

SPQ_LSH_GPU_25M_chosen = SPQ_LSH_GPU_25M[idx_LSH_25M_nbits]
recall_LSH_GPU_25M_chosen = recall_LSH_GPU_25M[idx_LSH_25M_nbits]
memory_LSH_GPU_25M_chosen = memory_LSH_GPU_25M[idx_LSH_25M_nbits]
categories_LSH_25M_chosen = ["LSH\nnbits=32", "LSH\nnbits=64", "LSH\nnbits=128"]

# PQ_chosen:
# (m, nbits) = (8, 8), (32, 8), (8, 10) (32, 10) 
# print(SPQ_PQ.shape)
idx_PQ_25M_chosen = slice(0,4) # to account for the fact that we only tested 4 configurations of PQ at 25M
SPQ_PQ_CPU_25M_flat = SPQ_PQ_CPU_25M.flatten()
recall_PQ_CPU_25M_flat = recall_PQ_CPU_25M.flatten()
memory_PQ_CPU_25M_flat = memory_PQ_CPU_25M.flatten()
SPQ_PQ_CPU_25M_chosen = SPQ_PQ_CPU_25M_flat[idx_PQ_25M_chosen]
recall_PQ_CPU_25M_chosen = recall_PQ_CPU_25M_flat[idx_PQ_25M_chosen]
memory_PQ_CPU_25M_chosen = memory_PQ_CPU_25M_flat[idx_PQ_25M_chosen]
categories_PQ_25M_chosen = ["PQ\nm=8\nnbits=8", "PQ\nm=32\nnbits=8", "PQ\nm=8\nnbits=10", "PQ\nm=32\nnbits=10"]

SPQ_PQ_GPU_25M_flat = SPQ_PQ_GPU_25M.flatten()
recall_PQ_GPU_25M_flat = recall_PQ_GPU_25M.flatten()
memory_PQ_GPU_25M_flat = memory_PQ_GPU_25M.flatten()
SPQ_PQ_GPU_25M_chosen = SPQ_PQ_GPU_25M_flat[idx_PQ_25M_chosen]
recall_PQ_GPU_25M_chosen = recall_PQ_GPU_25M_flat[idx_PQ_25M_chosen]
memory_PQ_GPU_25M_chosen = memory_PQ_GPU_25M_flat[idx_PQ_25M_chosen]

# HNSW_chosen:
idx_HNSW_25M_chosen = slice(0, 2)
SPQ_HNSW_CPU_25M_chosen = SPQ_HNSW_CPU_25M[idx_HNSW_25M_chosen]
recall_HNSW_CPU_25M_chosen = recall_HNSW_CPU_25M[idx_HNSW_25M_chosen]
memory_HNSW_CPU_25M_chosen = memory_HNSW_CPU_25M[idx_HNSW_25M_chosen]

SPQ_HNSW_GPU_25M_chosen = SPQ_HNSW_GPU_25M[idx_HNSW_25M_chosen]
recall_HNSW_GPU_25M_chosen = recall_HNSW_GPU_25M[idx_HNSW_25M_chosen]
memory_HNSW_GPU_25M_chosen = memory_HNSW_GPU_25M[idx_HNSW_25M_chosen]
categories_HNSW_25M_chosen = ["HNSW\nM=4", "HNSW\nM=8"]

# Plot
# Next we create 3 plots: 1) SPQ 2) memory, 3) recall
# For every plot, we plot the results for the methods with chosen parameters on both CPU and GPU (the bar for CPU and GPU are next to each other)
# FlatL2 should be on the left most of every plot as it is the baseline
# The order of the methods on the plot is: FlatL2, LSH, PQ, HNSW
figsize = (15, 5)
categories = categories_FlatL2_chosen + categories_LSH_25M_chosen + categories_PQ_25M_chosen + categories_HNSW_25M_chosen

# SPQ
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, sharex=True, figsize=figsize)
SPQ_CPU = np.concatenate((SPQ_FlatL2_CPU_25M_chosen.reshape(-1), SPQ_LSH_CPU_25M_chosen, SPQ_PQ_CPU_25M_chosen, SPQ_HNSW_CPU_25M_chosen))
SPQ_GPU = np.concatenate((SPQ_FlatL2_GPU_25M_chosen.reshape(-1), SPQ_LSH_GPU_25M_chosen, SPQ_PQ_GPU_25M_chosen, SPQ_HNSW_GPU_25M_chosen))
ax1.bar(np.arange(len(categories)), SPQ_CPU, width=0.4, label='CPU')
ax1.bar(np.arange(len(categories))+0.4, SPQ_GPU, width=0.4, label='GPU')
#ax1.set_ylabel('Time per query (ms)')
ax1.set_ylim(3, 10)
ax1.set_title('Time per query for different methods on 25M dataset')
ax1.legend(loc='best')
ax2.bar(np.arange(len(categories)), SPQ_CPU, width=0.4, label='CPU')
ax2.bar(np.arange(len(categories))+0.4, SPQ_GPU, width=0.4, label='GPU')
ax2.set_ylim(0.5, 3)
ax3.bar(np.arange(len(categories)), SPQ_CPU, width=0.4, label='CPU')
ax3.bar(np.arange(len(categories))+0.4, SPQ_GPU, width=0.4, label='GPU')
ax3.set_ylim(0.0007, 0.5)
ax4.bar(np.arange(len(categories)), SPQ_CPU, width=0.4, label='CPU')
ax4.bar(np.arange(len(categories))+0.4, SPQ_GPU, width=0.4, label='GPU')
ax4.set_ylim(0, 0.0007)
plt.ylabel('Time per query (ms)')
plt.xlabel('Index')
plt.xticks(np.arange(len(categories))+0.2, categories, rotation=45)
# plt.savefig('/home/ypx/faissTesting/benchmark/charts/SPQ_25M_CPUvsGPU.png')
plt.show()

# Memory
plt.figure(figsize=figsize)
memory_CPU = np.concatenate((memory_FlatL2_CPU_25M_chosen.reshape(-1), memory_LSH_CPU_25M_chosen, memory_PQ_CPU_25M_chosen, memory_HNSW_CPU_25M_chosen))
memory_GPU = np.concatenate((memory_FlatL2_GPU_25M_chosen.reshape(-1), memory_LSH_GPU_25M_chosen, memory_PQ_GPU_25M_chosen, memory_HNSW_GPU_25M_chosen))
plt.bar(np.arange(len(categories)), memory_CPU, width=0.4, label='CPU')
plt.bar(np.arange(len(categories))+0.4, memory_GPU, width=0.4, label='GPU')
plt.ylabel('Memory (MB)')
plt.xlabel('Index')
plt.xticks(np.arange(len(categories))+0.2, categories, rotation=45)
plt.title('Memory usage for different methods on 25M dataset')
plt.legend(loc='best')
# plt.savefig('/home/ypx/faissTesting/benchmark/charts/memory_25M_CPUvsGPU.png')
plt.show()

# Recall
plt.figure(figsize=figsize)
recall_CPU = np.concatenate((recall_FlatL2_CPU_25M_chosen.reshape(-1), recall_LSH_CPU_25M_chosen, recall_PQ_CPU_25M_chosen, recall_HNSW_CPU_25M_chosen))
recall_GPU = np.concatenate((recall_FlatL2_GPU_25M_chosen.reshape(-1), recall_LSH_GPU_25M_chosen, recall_PQ_GPU_25M_chosen, recall_HNSW_GPU_25M_chosen))
plt.bar(np.arange(len(categories)), recall_CPU, width=0.4, label='CPU')
plt.bar(np.arange(len(categories))+0.4, recall_GPU, width=0.4, label='GPU')
plt.ylabel('Recall')
plt.xlabel('Index')
plt.xticks(np.arange(len(categories))+0.2, categories, rotation=45)
plt.title('Recall for different methods on 25M dataset')
plt.legend(loc='best')
# plt.savefig('/home/ypx/faissTesting/benchmark/charts/recall_25M_CPUvsGPU.png')
plt.show()

# %%
# GPU vs CPU (50M): 
# FlatL2_chosen:
SPQ_FlatL2_CPU_50M_chosen = SPQ_FlatL2_CPU_50M
recall_FlatL2_CPU_50M_chosen = recall_FlatL2_CPU_50M
memory_FlatL2_CPU_50M_chosen = memory_FlatL2_CPU_50M

SPQ_FlatL2_GPU_50M_chosen = SPQ_FlatL2_GPU_50M
recall_FlatL2_GPU_50M_chosen = recall_FlatL2_GPU_50M
memory_FlatL2_GPU_50M_chosen = memory_FlatL2_GPU_50M
categories_FlatL2_chosen = ["Exact search\n(baseline)"]

# LSH_chosen:
idx_LSH_50M_nbits = slice(5, 8)
SPQ_LSH_CPU_50M_chosen = SPQ_LSH_CPU_50M[idx_LSH_50M_nbits]
recall_LSH_CPU_50M_chosen = recall_LSH_CPU_50M[idx_LSH_50M_nbits]
memory_LSH_CPU_50M_chosen = memory_LSH_CPU_50M[idx_LSH_50M_nbits]

SPQ_LSH_GPU_50M_chosen = SPQ_LSH_GPU_50M[idx_LSH_50M_nbits]
recall_LSH_GPU_50M_chosen = recall_LSH_GPU_50M[idx_LSH_50M_nbits]
memory_LSH_GPU_50M_chosen = memory_LSH_GPU_50M[idx_LSH_50M_nbits]
categories_LSH_50M_chosen = ["LSH\nnbits=32", "LSH\nnbits=64", "LSH\nnbits=128"]

# PQ_chosen:
# (m, nbits) = (8, 8), (32, 8), (8, 10) (32, 10) 
# print(SPQ_PQ.shape)
idx_PQ_50M_chosen = slice(0,4) # to account for the fact that we only tested 4 configurations of PQ at 50M
SPQ_PQ_CPU_50M_flat = SPQ_PQ_CPU_50M.flatten()
recall_PQ_CPU_50M_flat = recall_PQ_CPU_50M.flatten()
memory_PQ_CPU_50M_flat = memory_PQ_CPU_50M.flatten()
SPQ_PQ_CPU_50M_chosen = SPQ_PQ_CPU_50M_flat[idx_PQ_50M_chosen]
recall_PQ_CPU_50M_chosen = recall_PQ_CPU_50M_flat[idx_PQ_50M_chosen]
memory_PQ_CPU_50M_chosen = memory_PQ_CPU_50M_flat[idx_PQ_50M_chosen]
categories_PQ_50M_chosen = ["PQ\nm=8\nnbits=8", "PQ\nm=32\nnbits=8", "PQ\nm=8\nnbits=10", "PQ\nm=32\nnbits=10"]

SPQ_PQ_GPU_50M_flat = SPQ_PQ_GPU_50M.flatten()
recall_PQ_GPU_50M_flat = recall_PQ_GPU_50M.flatten()
memory_PQ_GPU_50M_flat = memory_PQ_GPU_50M.flatten()
SPQ_PQ_GPU_50M_chosen = SPQ_PQ_GPU_50M_flat[idx_PQ_50M_chosen]
recall_PQ_GPU_50M_chosen = recall_PQ_GPU_50M_flat[idx_PQ_50M_chosen]
memory_PQ_GPU_50M_chosen = memory_PQ_GPU_50M_flat[idx_PQ_50M_chosen]

# HNSW_chosen:
idx_HNSW_50M_chosen = slice(0, 1)
SPQ_HNSW_CPU_50M_chosen = SPQ_HNSW_CPU_50M[idx_HNSW_50M_chosen]
recall_HNSW_CPU_50M_chosen = recall_HNSW_CPU_50M[idx_HNSW_50M_chosen]
memory_HNSW_CPU_50M_chosen = memory_HNSW_CPU_50M[idx_HNSW_50M_chosen]

SPQ_HNSW_GPU_50M_chosen = SPQ_HNSW_GPU_50M[idx_HNSW_50M_chosen]
recall_HNSW_GPU_50M_chosen = recall_HNSW_GPU_50M[idx_HNSW_50M_chosen]
memory_HNSW_GPU_50M_chosen = memory_HNSW_GPU_50M[idx_HNSW_50M_chosen]
categories_HNSW_50M_chosen = ["HNSW\nM=4"]

# Plot
# Next we create 3 plots: 1) SPQ 2) memory, 3) recall
# For every plot, we plot the results for the methods with chosen parameters on both CPU and GPU (the bar for CPU and GPU are next to each other)
# FlatL2 should be on the left most of every plot as it is the baseline
# The order of the methods on the plot is: FlatL2, LSH, PQ, HNSW
figsize = (15, 5)
categories = categories_FlatL2_chosen + categories_LSH_50M_chosen + categories_PQ_50M_chosen + categories_HNSW_50M_chosen

# SPQ
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, sharex=True, figsize=figsize)
SPQ_CPU = np.concatenate((SPQ_FlatL2_CPU_50M_chosen.reshape(-1), SPQ_LSH_CPU_50M_chosen, SPQ_PQ_CPU_50M_chosen, SPQ_HNSW_CPU_50M_chosen))
SPQ_GPU = np.concatenate((SPQ_FlatL2_GPU_50M_chosen.reshape(-1), SPQ_LSH_GPU_50M_chosen, SPQ_PQ_GPU_50M_chosen, SPQ_HNSW_GPU_50M_chosen))
ax1.bar(np.arange(len(categories)), SPQ_CPU, width=0.4, label='CPU')
ax1.bar(np.arange(len(categories))+0.4, SPQ_GPU, width=0.4, label='GPU')
ax1.set_ylim(4, 20)
ax1.set_title('Time per query for different methods on 50M dataset')
ax1.legend(loc='best')
ax2.bar(np.arange(len(categories)), SPQ_CPU, width=0.4, label='CPU')
ax2.bar(np.arange(len(categories))+0.4, SPQ_GPU, width=0.4, label='GPU')
ax2.set_ylim(1.2, 4)
ax3.bar(np.arange(len(categories)), SPQ_CPU, width=0.4, label='CPU')
ax3.bar(np.arange(len(categories))+0.4, SPQ_GPU, width=0.4, label='GPU')
ax3.set_ylim(0.001, 1.2)
ax4.bar(np.arange(len(categories)), SPQ_CPU, width=0.4, label='CPU')
ax4.bar(np.arange(len(categories))+0.4, SPQ_GPU, width=0.4, label='GPU')
ax4.set_ylim(0, 0.001)
plt.ylabel('Time per query (ms)')
plt.xlabel('Index')
plt.xticks(np.arange(len(categories))+0.2, categories, rotation=45)
# plt.savefig('/home/ypx/faissTesting/benchmark/charts/SPQ_50M_CPUvsGPU.png')
plt.show()

# Memory
plt.figure(figsize=figsize)
memory_CPU = np.concatenate((memory_FlatL2_CPU_50M_chosen.reshape(-1), memory_LSH_CPU_50M_chosen, memory_PQ_CPU_50M_chosen, memory_HNSW_CPU_50M_chosen))
memory_GPU = np.concatenate((memory_FlatL2_GPU_50M_chosen.reshape(-1), memory_LSH_GPU_50M_chosen, memory_PQ_GPU_50M_chosen, memory_HNSW_GPU_50M_chosen))
plt.bar(np.arange(len(categories)), memory_CPU, width=0.4, label='CPU')
plt.bar(np.arange(len(categories))+0.4, memory_GPU, width=0.4, label='GPU')
plt.ylabel('Memory (MB)')
plt.xlabel('Index')
plt.xticks(np.arange(len(categories))+0.2, categories, rotation=45)
plt.title('Memory usage for different methods on 50M dataset')
plt.legend(loc='best')
# plt.savefig('/home/ypx/faissTesting/benchmark/charts/memory_50M_CPUvsGPU.png')
plt.show()

# Recall
plt.figure(figsize=figsize)
recall_CPU = np.concatenate((recall_FlatL2_CPU_50M_chosen.reshape(-1), recall_LSH_CPU_50M_chosen, recall_PQ_CPU_50M_chosen, recall_HNSW_CPU_50M_chosen))
recall_GPU = np.concatenate((recall_FlatL2_GPU_50M_chosen.reshape(-1), recall_LSH_GPU_50M_chosen, recall_PQ_GPU_50M_chosen, recall_HNSW_GPU_50M_chosen))
plt.bar(np.arange(len(categories)), recall_CPU, width=0.4, label='CPU')
plt.bar(np.arange(len(categories))+0.4, recall_GPU, width=0.4, label='GPU')
plt.ylabel('Recall')
plt.xlabel('Index')
plt.xticks(np.arange(len(categories))+0.2, categories, rotation=45)
plt.title('Recall for different methods on 50M dataset')
plt.legend(loc='best')
# plt.savefig('/home/ypx/faissTesting/benchmark/charts/recall_50M_CPUvsGPU.png')
plt.show()

# %%
# 10M vs 25M vs 50M (CPU)
# Use the same parameters for all methods

# FlatL2_chosen:
SPQ_FlatL2_CPU_10M_chosen # already exists
SPQ_FlatL2_CPU_25M_chosen # already exists
SPQ_FlatL2_CPU_50M_chosen # already exists

recall_FlatL2_CPU_10M_chosen # already exists
recall_FlatL2_CPU_25M_chosen # already exists
recall_FlatL2_CPU_50M_chosen # already exists

memory_FlatL2_CPU_10M_chosen # already exists
memory_FlatL2_CPU_25M_chosen # already exists
memory_FlatL2_CPU_50M_chosen # already exists

# LSH_chosen:
SPQ_LSH_CPU_10M_chosen # already exists
SPQ_LSH_CPU_25M_chosen # already exists
SPQ_LSH_CPU_50M_chosen # already exists

recall_LSH_CPU_10M_chosen # already exists
recall_LSH_CPU_25M_chosen # already exists
recall_LSH_CPU_50M_chosen # already exists

memory_LSH_CPU_10M_chosen # already exists
memory_LSH_CPU_25M_chosen # already exists
memory_LSH_CPU_50M_chosen # already exists

categories_LSH_chosen = ["LSH\nnbits=32", "LSH\nnbits=64", "LSH\nnbits=128"]

# PQ_chosen:
SPQ_PQ_CPU_10M_chosen # already exists
SPQ_PQ_CPU_25M_chosen # already exists
SPQ_PQ_CPU_50M_chosen # already exists

recall_PQ_CPU_10M_chosen # already exists
recall_PQ_CPU_25M_chosen # already exists
recall_PQ_CPU_50M_chosen # already exists

memory_PQ_CPU_10M_chosen # already exists
memory_PQ_CPU_25M_chosen # already exists
memory_PQ_CPU_50M_chosen # already exists

categories_PQ_chosen = ["PQ\nm=8\nnbits=8", "PQ\nm=32\nnbits=8", "PQ\nm=8\nnbits=10", "PQ\nm=32\nnbits=10"]

# HNSW_chosen:
# excluded for now

# Plot
# Next we create 3 plots: 1) SPQ 2) memory, 3) recall
# For every plot, we plot the results for the methods with chosen parameters on all 10M, 25M, and 50M data sizes (three bar next to each other)
# FlatL2 should be on the left most of every plot as it is the baseline
# The order of the methods on the plot is: FlatL2, LSH, PQ
# HNSW is excluded because no overlap of parameters with 10M, 25M, and 50M so far (with current limit of memory, only up to M = 4 is possible for 50M)
figsize = (15, 5)
categories = categories_FlatL2_chosen + categories_LSH_chosen + categories_PQ_chosen

# SPQ
plt.figure(figsize=figsize)
SPQ_10M = np.concatenate((SPQ_FlatL2_CPU_10M_chosen.reshape(-1), SPQ_LSH_CPU_10M_chosen, SPQ_PQ_CPU_10M_chosen))
SPQ_25M = np.concatenate((SPQ_FlatL2_CPU_25M_chosen.reshape(-1), SPQ_LSH_CPU_25M_chosen, SPQ_PQ_CPU_25M_chosen))
SPQ_50M = np.concatenate((SPQ_FlatL2_CPU_50M_chosen.reshape(-1), SPQ_LSH_CPU_50M_chosen, SPQ_PQ_CPU_50M_chosen))
plt.bar(np.arange(len(categories)), SPQ_10M, width=0.25, label='10M')
plt.bar(np.arange(len(categories))+0.25, SPQ_25M, width=0.25, label='25M')
plt.bar(np.arange(len(categories))+0.5, SPQ_50M, width=0.25, label='50M')
plt.xticks(np.arange(len(categories))+0.25, categories)
plt.title('Time per query for different data sizes on CPU')
plt.ylabel('Time per query (ms)')
plt.legend()
plt.savefig('/home/ypx/faissTesting/benchmark/charts/SPQ_CPU_10Mvs25Mvs50M.png')
plt.show()

# memory
plt.figure(figsize=figsize)
memory_10M = np.concatenate((memory_FlatL2_CPU_10M_chosen.reshape(-1), memory_LSH_CPU_10M_chosen, memory_PQ_CPU_10M_chosen))
memory_25M = np.concatenate((memory_FlatL2_CPU_25M_chosen.reshape(-1), memory_LSH_CPU_25M_chosen, memory_PQ_CPU_25M_chosen))
memory_50M = np.concatenate((memory_FlatL2_CPU_50M_chosen.reshape(-1), memory_LSH_CPU_50M_chosen, memory_PQ_CPU_50M_chosen))
plt.bar(np.arange(len(categories)), memory_10M, width=0.25, label='10M')
plt.bar(np.arange(len(categories))+0.25, memory_25M, width=0.25, label='25M')
plt.bar(np.arange(len(categories))+0.5, memory_50M, width=0.25, label='50M')
plt.xticks(np.arange(len(categories))+0.25, categories)
plt.title('Memory usage for different data sizes on CPU')
plt.ylabel('Memory usage (MB)')
plt.legend()
plt.savefig('/home/ypx/faissTesting/benchmark/charts/memory_CPU_10Mvs25Mvs50M.png')
plt.show()

# recall
plt.figure(figsize=figsize)
recall_10M = np.concatenate((recall_FlatL2_CPU_10M_chosen.reshape(-1), recall_LSH_CPU_10M_chosen, recall_PQ_CPU_10M_chosen))
recall_25M = np.concatenate((recall_FlatL2_CPU_25M_chosen.reshape(-1), recall_LSH_CPU_25M_chosen, recall_PQ_CPU_25M_chosen))
recall_50M = np.concatenate((recall_FlatL2_CPU_50M_chosen.reshape(-1), recall_LSH_CPU_50M_chosen, recall_PQ_CPU_50M_chosen))
plt.bar(np.arange(len(categories)), recall_10M, width=0.25, label='10M')
plt.bar(np.arange(len(categories))+0.25, recall_25M, width=0.25, label='25M')
plt.bar(np.arange(len(categories))+0.5, recall_50M, width=0.25, label='50M')
plt.xticks(np.arange(len(categories))+0.25, categories)
plt.title('Recall for different data sizes on CPU')
plt.ylabel('Recall')
plt.legend()
plt.savefig('/home/ypx/faissTesting/benchmark/charts/recall_CPU_10Mvs25Mvs50M.png')
plt.show()

# %%
# 10M vs 25M vs 50M (GPU)
# Use the same parameters for all methods

# FlatL2_chosen:
SPQ_FlatL2_GPU_10M_chosen # already exists
SPQ_FlatL2_GPU_25M_chosen # already exists
SPQ_FlatL2_GPU_50M_chosen # already exists

recall_FlatL2_GPU_10M_chosen # already exists
recall_FlatL2_GPU_25M_chosen # already exists
recall_FlatL2_GPU_50M_chosen # already exists

memory_FlatL2_GPU_10M_chosen # already exists
memory_FlatL2_GPU_25M_chosen # already exists
memory_FlatL2_GPU_50M_chosen # already exists

# LSH_chosen:
SPQ_LSH_GPU_10M_chosen # already exists
SPQ_LSH_GPU_25M_chosen # already exists
SPQ_LSH_GPU_50M_chosen # already exists

recall_LSH_GPU_10M_chosen # already exists
recall_LSH_GPU_25M_chosen # already exists
recall_LSH_GPU_50M_chosen # already exists

memory_LSH_GPU_10M_chosen # already exists
memory_LSH_GPU_25M_chosen # already exists
memory_LSH_GPU_50M_chosen # already exists

categories_LSH_chosen = ["LSH\nnbits=32", "LSH\nnbits=64", "LSH\nnbits=128"]

# PQ_chosen:
SPQ_PQ_GPU_10M_chosen # already exists
SPQ_PQ_GPU_25M_chosen # already exists
SPQ_PQ_GPU_50M_chosen # already exists

recall_PQ_GPU_10M_chosen # already exists
recall_PQ_GPU_25M_chosen # already exists
recall_PQ_GPU_50M_chosen # already exists

memory_PQ_GPU_10M_chosen # already exists
memory_PQ_GPU_25M_chosen # already exists
memory_PQ_GPU_50M_chosen # already exists

categories_PQ_chosen = ["PQ\nm=8\nnbits=8", "PQ\nm=32\nnbits=8", "PQ\nm=8\nnbits=10", "PQ\nm=32\nnbits=10"]

# HNSW_chosen:
# excluded for now

# Plot
# Next we create 3 plots: 1) SPQ 2) memory, 3) recall
# For every plot, we plot the results for the methods with chosen parameters on all 10M, 25M, and 50M data sizes (three bar next to each other)
# FlatL2 should be on the left most of every plot as it is the baseline
# The order of the methods on the plot is: FlatL2, LSH, PQ
# HNSW is excluded because no overlap of parameters with 10M, 25M, and 50M so far (with current limit of memory, only up to M = 4 is possible for 50M)
figsize = (15, 5)
categories = categories_FlatL2_chosen + categories_LSH_chosen + categories_PQ_chosen

# SPQ
plt.figure(figsize=figsize)
SPQ_10M = np.concatenate((SPQ_FlatL2_GPU_10M_chosen.reshape(-1), SPQ_LSH_GPU_10M_chosen, SPQ_PQ_GPU_10M_chosen))
SPQ_25M = np.concatenate((SPQ_FlatL2_GPU_25M_chosen.reshape(-1), SPQ_LSH_GPU_25M_chosen, SPQ_PQ_GPU_25M_chosen))
SPQ_50M = np.concatenate((SPQ_FlatL2_GPU_50M_chosen.reshape(-1), SPQ_LSH_GPU_50M_chosen, SPQ_PQ_GPU_50M_chosen))
plt.bar(np.arange(len(categories)), SPQ_10M, width=0.25, label='10M')
plt.bar(np.arange(len(categories))+0.25, SPQ_25M, width=0.25, label='25M')
plt.bar(np.arange(len(categories))+0.5, SPQ_50M, width=0.25, label='50M')
plt.xticks(np.arange(len(categories))+0.25, categories)
plt.title('Time per query for different data sizes on GPU')
plt.ylabel('Time per query (ms)')
plt.legend()
plt.savefig('/home/ypx/faissTesting/benchmark/charts/SPQ_GPU_10Mvs25Mvs50M.png')
plt.show()

# memory
plt.figure(figsize=figsize)
memory_10M = np.concatenate((memory_FlatL2_GPU_10M_chosen.reshape(-1), memory_LSH_GPU_10M_chosen, memory_PQ_GPU_10M_chosen))
memory_25M = np.concatenate((memory_FlatL2_GPU_25M_chosen.reshape(-1), memory_LSH_GPU_25M_chosen, memory_PQ_GPU_25M_chosen))
memory_50M = np.concatenate((memory_FlatL2_GPU_50M_chosen.reshape(-1), memory_LSH_GPU_50M_chosen, memory_PQ_GPU_50M_chosen))
plt.bar(np.arange(len(categories)), memory_10M, width=0.25, label='10M')
plt.bar(np.arange(len(categories))+0.25, memory_25M, width=0.25, label='25M')
plt.bar(np.arange(len(categories))+0.5, memory_50M, width=0.25, label='50M')
plt.xticks(np.arange(len(categories))+0.25, categories)
plt.title('Memory usage for different data sizes on GPU')
plt.ylabel('Memory usage (MB)')
plt.legend()
plt.savefig('/home/ypx/faissTesting/benchmark/charts/memory_GPU_10Mvs25Mvs50M.png')
plt.show()

# recall
plt.figure(figsize=figsize)
recall_10M = np.concatenate((recall_FlatL2_GPU_10M_chosen.reshape(-1), recall_LSH_GPU_10M_chosen, recall_PQ_GPU_10M_chosen))
recall_25M = np.concatenate((recall_FlatL2_GPU_25M_chosen.reshape(-1), recall_LSH_GPU_25M_chosen, recall_PQ_GPU_25M_chosen))
recall_50M = np.concatenate((recall_FlatL2_GPU_50M_chosen.reshape(-1), recall_LSH_GPU_50M_chosen, recall_PQ_GPU_50M_chosen))
plt.bar(np.arange(len(categories)), recall_10M, width=0.25, label='10M')
plt.bar(np.arange(len(categories))+0.25, recall_25M, width=0.25, label='25M')
plt.bar(np.arange(len(categories))+0.5, recall_50M, width=0.25, label='50M')
plt.xticks(np.arange(len(categories))+0.25, categories)
plt.title('Recall for different data sizes on GPU')
plt.ylabel('Recall')
plt.legend()
plt.savefig('/home/ypx/faissTesting/benchmark/charts/recall_GPU_10Mvs25Mvs50M.png')
plt.show()
